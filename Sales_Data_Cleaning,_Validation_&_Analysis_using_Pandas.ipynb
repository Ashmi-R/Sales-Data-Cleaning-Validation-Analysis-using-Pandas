# %%
# !pip install pandas
import pandas as pd

# %%
df=pd.read_csv('/content/sales_dataset_cleaned.csv')

# %%
df.head()
# Out:
#   Order_ID Customer_ID Product_ID  Order_Date Delivery_Date Region    Country  \
# 0  ORD1000    CUST8471   PROD7862  2023-06-09    2022-10-04   West        USA
# 1  ORD1001    CUST5056   PROD7934  2022-04-14    2022-08-02    NaN  Australia
# 2  ORD1002    CUST9913   PROD4741  2023-03-14    2022-11-07   East        NaN
# 3  ORD1003    CUST3074   PROD4564  2022-03-27    2023-02-07    NaN  Australia
# 4  ORD1004    CUST6136   PROD8542  2022-01-06    2023-03-10    NaN  Australia
#
#   Store_Name Customer_Name           Email  ... Payment_Status Shipping_Cost  \
# 0   Flipkart          Amit             NaN  ...            NaN         755.0
# 1     Amazon           NaN  amit@yahoo.com  ...            NaN         389.0
# 2     Amazon          Mary             NaN  ...        Pending         819.0
# 3     Amazon        Fatima             NaN  ...        Pending         517.0
# 4    Walmart          Mary           john@  ...        Pending           NaN
#
# ...

# %%
df.tail()
# Out:
#       Order_ID Customer_ID Product_ID  Order_Date Delivery_Date Region  \
# 9995  ORD10995    CUST7273   PROD6814  2023-05-15    2022-11-06  South
# 9996  ORD10996    CUST9931   PROD5202  2022-07-05    2023-12-23   East
# 9997  ORD10997    CUST5118   PROD1752  2023-03-29    2023-02-17  South
# 9998  ORD10998    CUST7702   PROD4664  2022-10-22    2023-07-22   West
# 9999  ORD10999    CUST9878   PROD2527  2022-01-07    2022-02-19   East
#
#         Country Store_Name Customer_Name           Email  ... Payment_Status  \
# 9995  Australia    BestBuy          Amit            ravi  ...            NaN
# 9996  Australia        NaN          Ravi             NaN  ...         Failed
# 9997        USA    Walmart          Mary            ravi  ...           Paid
# 9998        USA     Target          Mary  mary@gmail.com  ...            NaN
# 9999      India     Target         Priya  mary@gmail.com  ...         Failed
#
#      Shipping_Cost  Total_Amount Return_Status   Profit Feedback_Score  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 35 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        10000 non-null  object
#  1   Customer_ID     10000 non-null  object
#  2   Product_ID      10000 non-null  object
#  3   Order_Date      10000 non-null  object
#  4   Delivery_Date   10000 non-null  object
#  5   Region          7981 non-null   object
#  6   Country         7977 non-null   object
#  7   Store_Name      8369 non-null   object
#  8   Customer_Name   8559 non-null   object
#  9   Email           8062 non-null   object
#  10  Phone           7513 non-null   object
#  11  Gender          10000 non-null  object
#  12  Age             9500 non-null   float64
#  13  City            8335 non-null   object
#  14  State           8385 non-null   object
#  15  Account_Status  10000 non-null  object
#  16  Product_Name    8296 non-null   object
# ...

# %%
df.describe()
# Out:
#                Age     Discount         Price     Quantity  Shipping_Cost  \
# count  9500.000000  9500.000000   9500.000000  9500.000000    9500.000000
# mean     57.088947    44.364842  50084.571789    21.906211     502.354421
# std      35.816469    31.729711  29005.220732    15.800836     287.449640
# min      -5.000000   -10.000000   -500.000000    -5.000000       0.000000
# 25%      26.000000    16.000000  25126.750000     8.000000     255.000000
# 50%      57.000000    45.000000  50435.000000    22.000000     498.000000
# 75%      88.000000    72.000000  75408.250000    35.000000     753.000000
# max     119.000000    99.000000  99998.000000    49.000000     999.000000
#
#         Total_Amount        Profit  Feedback_Score
# count    9500.000000   9500.000000    10000.000000
# mean    99339.641684  22347.430105        2.489800
# std     57772.270227  15876.050021        1.703698
# min      -927.000000  -4995.000000        0.000000
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Customer_ID, Product_ID, Order_Date, Delivery_Date, Region, Country, Store_Name, Customer_Name, Email, Phone, Gender, Age, City, State, Account_Status, Product_Name, Category, Sub_Category, Brand, Supplier_Name, Discount, Price, Quantity, Payment_Mode, Payment_Status, Shipping_Cost, Total_Amount, Return_Status, Profit, Feedback_Score, Sales_Agent, Loyalty_Level, Coupon_Code, Remarks]
# Index: []
#
# [0 rows x 35 columns]

# %%
df = df.drop_duplicates()

# %%
print("Duplicates after removal:", df.duplicated().sum())
# Out:
# Duplicates after removal: 0

# %%
df['Order_ID'].duplicated().sum()
# Out:
# np.int64(0)

# %%
df = df.drop_duplicates(subset=['Order_ID'], keep='first')
print(df)
# Out:
#       Order_ID Customer_ID Product_ID  Order_Date Delivery_Date Region  \
# 0      ORD1000    CUST8471   PROD7862  2023-06-09    2022-10-04   West
# 1      ORD1001    CUST5056   PROD7934  2022-04-14    2022-08-02    NaN
# 2      ORD1002    CUST9913   PROD4741  2023-03-14    2022-11-07   East
# 3      ORD1003    CUST3074   PROD4564  2022-03-27    2023-02-07    NaN
# 4      ORD1004    CUST6136   PROD8542  2022-01-06    2023-03-10    NaN
# ...        ...         ...        ...         ...           ...    ...
# 9995  ORD10995    CUST7273   PROD6814  2023-05-15    2022-11-06  South
# 9996  ORD10996    CUST9931   PROD5202  2022-07-05    2023-12-23   East
# 9997  ORD10997    CUST5118   PROD1752  2023-03-29    2023-02-17  South
# 9998  ORD10998    CUST7702   PROD4664  2022-10-22    2023-07-22   West
# 9999  ORD10999    CUST9878   PROD2527  2022-01-07    2022-02-19   East
#
#         Country Store_Name Customer_Name           Email  ... Payment_Status  \
# ...

# %%
print("Remaining duplicate Order_IDs:", df['Order_ID'].duplicated().sum())
# Out:
# Remaining duplicate Order_IDs: 0

# %%
df['Customer_ID'].duplicated().sum()
# Out:
# np.int64(3711)

# %%
df = df.drop_duplicates(subset=['Customer_ID'], keep='first')
print(df)
# Out:
#       Order_ID Customer_ID Product_ID  Order_Date Delivery_Date Region  \
# 0      ORD1000    CUST8471   PROD7862  2023-06-09    2022-10-04   West
# 1      ORD1001    CUST5056   PROD7934  2022-04-14    2022-08-02    NaN
# 2      ORD1002    CUST9913   PROD4741  2023-03-14    2022-11-07   East
# 3      ORD1003    CUST3074   PROD4564  2022-03-27    2023-02-07    NaN
# 4      ORD1004    CUST6136   PROD8542  2022-01-06    2023-03-10    NaN
# ...        ...         ...        ...         ...           ...    ...
# 9991  ORD10991    CUST2448   PROD2283  2022-02-01    2023-06-17    NaN
# 9993  ORD10993    CUST3469   PROD9687  2022-09-16    2022-11-27   West
# 9995  ORD10995    CUST7273   PROD6814  2023-05-15    2022-11-06  South
# 9996  ORD10996    CUST9931   PROD5202  2022-07-05    2023-12-23   East
# 9997  ORD10997    CUST5118   PROD1752  2023-03-29    2023-02-17  South
#
#         Country Store_Name Customer_Name           Email  ... Payment_Status  \
# ...

# %%
print("Before removing duplicates:", df.shape)
# Out:
# Before removing duplicates: (6289, 35)

# %%
print("After removing duplicates:", df.shape)
# Out:
# After removing duplicates: (6289, 35)

# %%
duplicate_emails = df[df.duplicated(subset=['Email'], keep=False)]
duplicate_emails[['Email']]
# Out:
#                Email
# 0                NaN
# 1     amit@yahoo.com
# 2                NaN
# 3                NaN
# 4              john@
# ...              ...
# 9991  mary@gmail.com
# 9993  mary@gmail.com
# 9995            ravi
# 9996             NaN
# 9997            ravi
#
# [6289 rows x 1 columns]

# %%
print("Duplicate email count:", df['Email'].duplicated().sum())
# Out:
# Duplicate email count: 6284

# %%
df = df.drop_duplicates(subset=['Email'], keep='first')

# %%
print(df)
# Out:
#    Order_ID Customer_ID Product_ID  Order_Date Delivery_Date Region  \
# 0   ORD1000    CUST8471   PROD7862  2023-06-09    2022-10-04   West
# 1   ORD1001    CUST5056   PROD7934  2022-04-14    2022-08-02    NaN
# 4   ORD1004    CUST6136   PROD8542  2022-01-06    2023-03-10    NaN
# 9   ORD1009    CUST9968    PROD538  2023-06-21    2023-12-01    NaN
# 12  ORD1012    CUST2051   PROD2742  2023-04-18    2023-04-27    NaN
#
#       Country Store_Name Customer_Name           Email  ... Payment_Status  \
# 0         USA   Flipkart          Amit             NaN  ...            NaN
# 1   Australia     Amazon           NaN  amit@yahoo.com  ...            NaN
# 4   Australia    Walmart          Mary           john@  ...        Pending
# 9         NaN    Walmart          Amit  mary@gmail.com  ...           Paid
# 12        USA     Target          Ravi            ravi  ...         Failed
#
#    Shipping_Cost  Total_Amount Return_Status   Profit Feedback_Score  \
# ...

# %%
print("Remaining duplicate emails:", df['Email'].duplicated().sum())
df
# Out:
# Remaining duplicate emails: 0
#    Order_ID Customer_ID Product_ID  Order_Date Delivery_Date Region  \
# 0   ORD1000    CUST8471   PROD7862  2023-06-09    2022-10-04   West
# 1   ORD1001    CUST5056   PROD7934  2022-04-14    2022-08-02    NaN
# 4   ORD1004    CUST6136   PROD8542  2022-01-06    2023-03-10    NaN
# 9   ORD1009    CUST9968    PROD538  2023-06-21    2023-12-01    NaN
# 12  ORD1012    CUST2051   PROD2742  2023-04-18    2023-04-27    NaN
#
#       Country Store_Name Customer_Name           Email  ... Payment_Status  \
# 0         USA   Flipkart          Amit             NaN  ...            NaN
# 1   Australia     Amazon           NaN  amit@yahoo.com  ...            NaN
# 4   Australia    Walmart          Mary           john@  ...        Pending
# 9         NaN    Walmart          Amit  mary@gmail.com  ...           Paid
# 12        USA     Target          Ravi            ravi  ...         Failed
#
#    Shipping_Cost  Total_Amount Return_Status   Profit Feedback_Score  \
# ...

# %%
df[['Customer_ID', 'Email']].head(10)
# Out:
#    Customer_ID           Email
# 0     CUST8471             NaN
# 1     CUST5056  amit@yahoo.com
# 4     CUST6136           john@
# 9     CUST9968  mary@gmail.com
# 12    CUST2051            ravi

# %%
df['Customer_Name'] = df['Customer_Name'].fillna('Unknown')
df
# Out:
#    Order_ID Customer_ID Product_ID  Order_Date Delivery_Date Region  \
# 0   ORD1000    CUST8471   PROD7862  2023-06-09    2022-10-04   West
# 1   ORD1001    CUST5056   PROD7934  2022-04-14    2022-08-02    NaN
# 4   ORD1004    CUST6136   PROD8542  2022-01-06    2023-03-10    NaN
# 9   ORD1009    CUST9968    PROD538  2023-06-21    2023-12-01    NaN
# 12  ORD1012    CUST2051   PROD2742  2023-04-18    2023-04-27    NaN
#
#       Country Store_Name Customer_Name           Email  ... Payment_Status  \
# 0         USA   Flipkart          Amit             NaN  ...            NaN
# 1   Australia     Amazon       Unknown  amit@yahoo.com  ...            NaN
# 4   Australia    Walmart          Mary           john@  ...        Pending
# 9         NaN    Walmart          Amit  mary@gmail.com  ...           Paid
# 12        USA     Target          Ravi            ravi  ...         Failed
#
#    Shipping_Cost  Total_Amount Return_Status   Profit Feedback_Score  \
# ...

# %%
df['Email'].isna().sum()
# Out:
# np.int64(1)

# %%
df['Email'] = df['Email'].fillna('noemail@example.com')
df
# Out:
#    Order_ID Customer_ID Product_ID  Order_Date Delivery_Date Region  \
# 0   ORD1000    CUST8471   PROD7862  2023-06-09    2022-10-04   West
# 1   ORD1001    CUST5056   PROD7934  2022-04-14    2022-08-02    NaN
# 4   ORD1004    CUST6136   PROD8542  2022-01-06    2023-03-10    NaN
# 9   ORD1009    CUST9968    PROD538  2023-06-21    2023-12-01    NaN
# 12  ORD1012    CUST2051   PROD2742  2023-04-18    2023-04-27    NaN
#
#       Country Store_Name Customer_Name                Email  ...  \
# 0         USA   Flipkart          Amit  noemail@example.com  ...
# 1   Australia     Amazon       Unknown       amit@yahoo.com  ...
# 4   Australia    Walmart          Mary                john@  ...
# 9         NaN    Walmart          Amit       mary@gmail.com  ...
# 12        USA     Target          Ravi                 ravi  ...
#
#    Payment_Status Shipping_Cost  Total_Amount Return_Status   Profit  \
# 0             NaN         755.0      199323.0       Pending  22394.0
# ...

# %%
df['Product_Name'] = df['Product_Name'].fillna('Misc Product')
df
# Out:
#    Order_ID Customer_ID Product_ID  Order_Date Delivery_Date Region  \
# 0   ORD1000    CUST8471   PROD7862  2023-06-09    2022-10-04   West
# 1   ORD1001    CUST5056   PROD7934  2022-04-14    2022-08-02    NaN
# 4   ORD1004    CUST6136   PROD8542  2022-01-06    2023-03-10    NaN
# 9   ORD1009    CUST9968    PROD538  2023-06-21    2023-12-01    NaN
# 12  ORD1012    CUST2051   PROD2742  2023-04-18    2023-04-27    NaN
#
#       Country Store_Name Customer_Name                Email  ...  \
# 0         USA   Flipkart          Amit  noemail@example.com  ...
# 1   Australia     Amazon       Unknown       amit@yahoo.com  ...
# 4   Australia    Walmart          Mary                john@  ...
# 9         NaN    Walmart          Amit       mary@gmail.com  ...
# 12        USA     Target          Ravi                 ravi  ...
#
#    Payment_Status Shipping_Cost  Total_Amount Return_Status   Profit  \
# 0             NaN         755.0      199323.0       Pending  22394.0
# ...

# %%
df['Product_Name'] = df['Product_Name'].fillna('Misc Product')

# %%
df['Category'] = df['Category'].fillna('Others')
df
# Out:
#    Order_ID Customer_ID Product_ID  Order_Date Delivery_Date Region  \
# 0   ORD1000    CUST8471   PROD7862  2023-06-09    2022-10-04   West
# 1   ORD1001    CUST5056   PROD7934  2022-04-14    2022-08-02    NaN
# 4   ORD1004    CUST6136   PROD8542  2022-01-06    2023-03-10    NaN
# 9   ORD1009    CUST9968    PROD538  2023-06-21    2023-12-01    NaN
# 12  ORD1012    CUST2051   PROD2742  2023-04-18    2023-04-27    NaN
#
#       Country Store_Name Customer_Name                Email  ...  \
# 0         USA   Flipkart          Amit  noemail@example.com  ...
# 1   Australia     Amazon       Unknown       amit@yahoo.com  ...
# 4   Australia    Walmart          Mary                john@  ...
# 9         NaN    Walmart          Amit       mary@gmail.com  ...
# 12        USA     Target          Ravi                 ravi  ...
#
#    Payment_Status Shipping_Cost  Total_Amount Return_Status   Profit  \
# 0             NaN         755.0      199323.0       Pending  22394.0
# ...

# %%
df[['Category']].head(20)
# Out:
#        Category
# 0   Electronics
# 1       Fashion
# 4        Others
# 9       Grocery
# 12       Others

# %%
df['Category'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Price'].mean()
# Out:
# np.float64(57498.2)

# %%
df['Price'] = df['Price'].fillna(
    df.groupby('Category')['Price'].transform('mean')
)

# %%
df[['Category', 'Price']].head(20)
# Out:
#        Category    Price
# 0   Electronics  52766.0
# 1       Fashion  82505.0
# 4        Others  10707.0
# 9       Grocery  62535.0
# 12       Others  78978.0

# %%
df['Price'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Price'] = df['Price'].fillna(57498.2)

# %%
df[['Category', 'Price']].head(20)
# Out:
#        Category    Price
# 0   Electronics  52766.0
# 1       Fashion  82505.0
# 4        Others  10707.0
# 9       Grocery  62535.0
# 12       Others  78978.0

# %%
df['Price'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Quantity'].isna().sum()
# Out:
# np.int64(0)

# %%
(df['Price'] <= 0).sum()
# Out:
# np.int64(0)

# %%
(df['Quantity'] <= 0).sum()
# Out:
# np.int64(1)

# %%
df[df['Quantity'] <= 0]
# Out:
#   Order_ID Customer_ID Product_ID  Order_Date Delivery_Date Region    Country  \
# 4  ORD1004    CUST6136   PROD8542  2022-01-06    2023-03-10    NaN  Australia
#
#   Store_Name Customer_Name  Email  ... Payment_Status Shipping_Cost  \
# 4    Walmart          Mary  john@  ...        Pending           NaN
#
#    Total_Amount Return_Status  Profit Feedback_Score Sales_Agent  \
# 4      157270.0      Returned  5182.0              2        Sita
#
#   Loyalty_Level Coupon_Code Remarks
# 4        Bronze      DISC20    Late
#
# [1 rows x 35 columns]

# %%
df = df[df['Quantity'] > 0]

# %%
(df['Quantity'] <= 0).sum()
# Out:
# np.int64(0)

# %%
(df['Profit'] < -1000).sum()
# Out:
# np.int64(0)

# %%
((df['Age'] < 0) | (df['Age'] > 120)).sum()
# Out:
# np.int64(0)

# %%
df[df['Delivery_Date'] < df['Order_Date']]
# Out:
#   Order_ID Customer_ID Product_ID  Order_Date Delivery_Date Region Country  \
# 0  ORD1000    CUST8471   PROD7862  2023-06-09    2022-10-04   West     USA
#
#   Store_Name Customer_Name                Email  ... Payment_Status  \
# 0   Flipkart          Amit  noemail@example.com  ...            NaN
#
#   Shipping_Cost  Total_Amount Return_Status   Profit Feedback_Score  \
# 0         755.0      199323.0       Pending  22394.0              3
#
#   Sales_Agent Loyalty_Level Coupon_Code Remarks
# 0         NaN           VIP      SAVE10    Late
#
# [1 rows x 35 columns]

# %%
(df['Delivery_Date'] < df['Order_Date']).sum()
# Out:
# np.int64(1)

# %%
df['Gender'].replace({'Mle': 'Male', 'F': 'Female', 'Fmale': 'Female'}, inplace=True)

# %%
df['Gender'].value_counts()
# Out:
# Gender
# Female    3
# Other     1
# Name: count, dtype: int64

# %%
print(df.columns)
# Out:
# Index(['Order_ID', 'Customer_ID', 'Product_ID', 'Order_Date', 'Delivery_Date',
#        'Region', 'Country', 'Store_Name', 'Customer_Name', 'Email', 'Phone',
#        'Gender', 'Age', 'City', 'State', 'Account_Status', 'Product_Name',
#        'Category', 'Sub_Category', 'Brand', 'Supplier_Name', 'Discount',
#        'Price', 'Quantity', 'Payment_Mode', 'Payment_Status', 'Shipping_Cost',
#        'Total_Amount', 'Return_Status', 'Profit', 'Feedback_Score',
#        'Sales_Agent', 'Loyalty_Level', 'Coupon_Code', 'Remarks'],
#       dtype='object')

# %%
df['Gender'].head(20)
# Out:
# 0     Female
# 1      Other
# 9     Female
# 12    Female
# Name: Gender, dtype: object

# %%
df['Gender'].isna().sum()
# Out:
# np.int64(0)

# %%
df['Payment_Mode'].replace({'Cahs': 'Cash'}, inplace=True)

# %%
df['Payment_Mode'].value_counts()
# Out:
# Payment_Mode
# Cash    1
# Card    1
# Name: count, dtype: int64

# %%
df['Payment_Mode'].unique()
# Out:
# array(['Cash', nan, 'Card'], dtype=object)

# %%
df['Payment_Mode'].isna().sum()
# Out:
# np.int64(2)

# %%
len(df)
# Out:
# 4

# %%
df['Account_Status'] = df['Account_Status'].replace({
    'Actve': 'Active',
    'Actiive': 'Active',
    'Inactve': 'Inactive',
    'Inactve ': 'Inactive',
    'Closd': 'Closed',
    'Clsoed': 'Closed'
})

# %%
df.loc[df['Account_Status'].str.contains('Act', na=False), 'Account_Status'] = 'Active'
df.loc[df['Account_Status'].str.contains('Inact', na=False), 'Account_Status'] = 'Inactive'
df.loc[df['Account_Status'].str.contains('Clos', na=False), 'Account_Status'] = 'Closed'

# %%
df['Account_Status'].value_counts()
df
# Out:
#    Order_ID Customer_ID Product_ID  Order_Date Delivery_Date Region  \
# 0   ORD1000    CUST8471   PROD7862  2023-06-09    2022-10-04   West
# 1   ORD1001    CUST5056   PROD7934  2022-04-14    2022-08-02    NaN
# 9   ORD1009    CUST9968    PROD538  2023-06-21    2023-12-01    NaN
# 12  ORD1012    CUST2051   PROD2742  2023-04-18    2023-04-27    NaN
#
#       Country Store_Name Customer_Name                Email  ...  \
# 0         USA   Flipkart          Amit  noemail@example.com  ...
# 1   Australia     Amazon       Unknown       amit@yahoo.com  ...
# 9         NaN    Walmart          Amit       mary@gmail.com  ...
# 12        USA     Target          Ravi                 ravi  ...
#
#    Payment_Status Shipping_Cost  Total_Amount Return_Status   Profit  \
# 0             NaN         755.0      199323.0       Pending  22394.0
# 1             NaN         389.0      137570.0  Not Returned  49832.0
# 9            Paid         443.0      169930.0      Returned  35381.0
# ...

# %%
df['Account_Status'].head(20)
# Out:
# 0       Closed
# 1       Closed
# 9       Closed
# 12    Inactive
# Name: Account_Status, dtype: object

# %%
df['Account_Status'].value_counts(dropna=False)
# Out:
# Account_Status
# Closed      3
# Inactive    1
# Name: count, dtype: int64

# %%
df['Account_Status'] = df['Account_Status'].astype(str).str.strip()

# %%
df['Account_Status'].value_counts(dropna=False)
# Out:
# Account_Status
# Closed      3
# Inactive    1
# Name: count, dtype: int64

# %%
df['Account_Status'].head(15)
# Out:
# 0       Closed
# 1       Closed
# 9       Closed
# 12    Inactive
# Name: Account_Status, dtype: object

# %%
df['Account_Status'].dtype
# Out:
# dtype('O')

# %%
df['Account_Status'].head(20)
df
# Out:
#    Order_ID Customer_ID Product_ID  Order_Date Delivery_Date Region  \
# 0   ORD1000    CUST8471   PROD7862  2023-06-09    2022-10-04   West
# 1   ORD1001    CUST5056   PROD7934  2022-04-14    2022-08-02    NaN
# 9   ORD1009    CUST9968    PROD538  2023-06-21    2023-12-01    NaN
# 12  ORD1012    CUST2051   PROD2742  2023-04-18    2023-04-27    NaN
#
#       Country Store_Name Customer_Name                Email  ...  \
# 0         USA   Flipkart          Amit  noemail@example.com  ...
# 1   Australia     Amazon       Unknown       amit@yahoo.com  ...
# 9         NaN    Walmart          Amit       mary@gmail.com  ...
# 12        USA     Target          Ravi                 ravi  ...
#
#    Payment_Status Shipping_Cost  Total_Amount Return_Status   Profit  \
# 0             NaN         755.0      199323.0       Pending  22394.0
# 1             NaN         389.0      137570.0  Not Returned  49832.0
# 9            Paid         443.0      169930.0      Returned  35381.0
# ...

# %%
df.shape
# Out:
# (4, 35)

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'], format='%d-%m-%Y', errors='coerce')
df['Delivery_Date'] = pd.to_datetime(df['Delivery_Date'], format='%d-%m-%Y', errors='coerce')

# %%
(df['Delivery_Date'] < df['Order_Date']).sum()
# Out:
# np.int64(0)

# %%
df['Region'] = df['Region'].fillna('Unknown')
df['Country'] = df['Country'].fillna('Unknown')

# %%
(df['Delivery_Date'] < df['Order_Date']).sum()
# Out:
# np.int64(0)

# %%
df.shape
df.head()
# Out:
#    Order_ID Customer_ID Product_ID Order_Date Delivery_Date   Region  \
# 0   ORD1000    CUST8471   PROD7862        NaT           NaT     West
# 1   ORD1001    CUST5056   PROD7934        NaT           NaT  Unknown
# 9   ORD1009    CUST9968    PROD538        NaT           NaT  Unknown
# 12  ORD1012    CUST2051   PROD2742        NaT           NaT  Unknown
#
#       Country Store_Name Customer_Name                Email  ...  \
# 0         USA   Flipkart          Amit  noemail@example.com  ...
# 1   Australia     Amazon       Unknown       amit@yahoo.com  ...
# 9     Unknown    Walmart          Amit       mary@gmail.com  ...
# 12        USA     Target          Ravi                 ravi  ...
#
#    Payment_Status Shipping_Cost  Total_Amount Return_Status   Profit  \
# 0             NaN         755.0      199323.0       Pending  22394.0
# 1             NaN         389.0      137570.0  Not Returned  49832.0
# 9            Paid         443.0      169930.0      Returned  35381.0
# ...

# %%
invalid_emails = df[~df['Email'].str.contains(r'@.+\.', na=False)]
invalid_emails[['Email']].head(20)
# Out:
#    Email
# 12  ravi

# %%
len(invalid_emails)
# Out:
# 1

# %%
invalid_emails = df[~df['Email'].str.contains(r'@.+\.', na=False)]
len(invalid_emails)
# Out:
# 1

# %%
((df['Discount'].isna()) | (df['Discount'] < 0)).sum()
# Out:
# np.int64(1)

# %%
df[df['Discount'].isna() | (df['Discount'] < 0)][['Discount']]
# Out:
#    Discount
# 9       NaN

# %%
df.loc[df['Discount'].isna() | (df['Discount'] < 0), 'Discount'] = 0

# %%
((df['Discount'].isna()) | (df['Discount'] < 0)).sum()
# Out:
# np.int64(0)

# %%
high_price_orders = df[df['Price'] > 50000]
high_price_orders
# Out:
#    Order_ID Customer_ID Product_ID Order_Date Delivery_Date   Region  \
# 0   ORD1000    CUST8471   PROD7862        NaT           NaT     West
# 1   ORD1001    CUST5056   PROD7934        NaT           NaT  Unknown
# 9   ORD1009    CUST9968    PROD538        NaT           NaT  Unknown
# 12  ORD1012    CUST2051   PROD2742        NaT           NaT  Unknown
#
#       Country Store_Name Customer_Name                Email  ...  \
# 0         USA   Flipkart          Amit  noemail@example.com  ...
# 1   Australia     Amazon       Unknown       amit@yahoo.com  ...
# 9     Unknown    Walmart          Amit       mary@gmail.com  ...
# 12        USA     Target          Ravi                 ravi  ...
#
#    Payment_Status Shipping_Cost  Total_Amount Return_Status   Profit  \
# 0             NaN         755.0      199323.0       Pending  22394.0
# 1             NaN         389.0      137570.0  Not Returned  49832.0
# 9            Paid         443.0      169930.0      Returned  35381.0
# ...

# %%
high_price_orders[['Order_ID', 'Product_Name', 'Price']]
# Out:
#    Order_ID  Product_Name    Price
# 0   ORD1000            TV  52766.0
# 1   ORD1001        Laptop  82505.0
# 9   ORD1009  Misc Product  62535.0
# 12  ORD1012        Laptop  78978.0

# %%
len(high_price_orders)
# Out:
# 4

# %%
low_feedback_orders = df[df['Feedback_Score'] < 3]
low_feedback_orders
# Out:
#    Order_ID Customer_ID Product_ID Order_Date Delivery_Date   Region  \
# 1   ORD1001    CUST5056   PROD7934        NaT           NaT  Unknown
# 9   ORD1009    CUST9968    PROD538        NaT           NaT  Unknown
# 12  ORD1012    CUST2051   PROD2742        NaT           NaT  Unknown
#
#       Country Store_Name Customer_Name           Email  ... Payment_Status  \
# 1   Australia     Amazon       Unknown  amit@yahoo.com  ...            NaN
# 9     Unknown    Walmart          Amit  mary@gmail.com  ...           Paid
# 12        USA     Target          Ravi            ravi  ...         Failed
#
#    Shipping_Cost  Total_Amount Return_Status   Profit Feedback_Score  \
# 1          389.0      137570.0  Not Returned  49832.0              0
# 9          443.0      169930.0      Returned  35381.0              2
# 12         471.0      171053.0           NaN      NaN              2
#
#    Sales_Agent Loyalty_Level Coupon_Code    Remarks
# 1        Rahul          Gold         NaN        NaN
# ...

# %%
low_feedback_orders[['Order_ID', 'Customer_Name', 'Feedback_Score']]
# Out:
#    Order_ID Customer_Name  Feedback_Score
# 1   ORD1001       Unknown               0
# 9   ORD1009          Amit               2
# 12  ORD1012          Ravi               2

# %%
len(low_feedback_orders)
# Out:
# 3

# %%
vip_high_value = df[(df['Loyalty_Level'] == 'VIP') & (df['Total_Amount'] > 100000)]
vip_high_value
# Out:
#    Order_ID Customer_ID Product_ID Order_Date Delivery_Date   Region Country  \
# 0   ORD1000    CUST8471   PROD7862        NaT           NaT     West     USA
# 12  ORD1012    CUST2051   PROD2742        NaT           NaT  Unknown     USA
#
#    Store_Name Customer_Name                Email  ... Payment_Status  \
# 0    Flipkart          Amit  noemail@example.com  ...            NaN
# 12     Target          Ravi                 ravi  ...         Failed
#
#    Shipping_Cost  Total_Amount Return_Status   Profit Feedback_Score  \
# 0          755.0      199323.0       Pending  22394.0              3
# 12         471.0      171053.0           NaN      NaN              2
#
#    Sales_Agent Loyalty_Level Coupon_Code    Remarks
# 0          NaN           VIP      SAVE10       Late
# 12        Sita           VIP         NaN  Delivered
#
# [2 rows x 35 columns]

# %%
vip_high_value[['Order_ID', 'Customer_Name', 'Loyalty_Level', 'Total_Amount']]
# Out:
#    Order_ID Customer_Name Loyalty_Level  Total_Amount
# 0   ORD1000          Amit           VIP      199323.0
# 12  ORD1012          Ravi           VIP      171053.0

# %%
len(vip_high_value)
# Out:
# 2

# %%
closed_orders = df[df['Account_Status'] == 'Closed']
closed_orders
# Out:
#   Order_ID Customer_ID Product_ID Order_Date Delivery_Date   Region  \
# 0  ORD1000    CUST8471   PROD7862        NaT           NaT     West
# 1  ORD1001    CUST5056   PROD7934        NaT           NaT  Unknown
# 9  ORD1009    CUST9968    PROD538        NaT           NaT  Unknown
#
#      Country Store_Name Customer_Name                Email  ...  \
# 0        USA   Flipkart          Amit  noemail@example.com  ...
# 1  Australia     Amazon       Unknown       amit@yahoo.com  ...
# 9    Unknown    Walmart          Amit       mary@gmail.com  ...
#
#   Payment_Status Shipping_Cost  Total_Amount Return_Status   Profit  \
# 0            NaN         755.0      199323.0       Pending  22394.0
# 1            NaN         389.0      137570.0  Not Returned  49832.0
# 9           Paid         443.0      169930.0      Returned  35381.0
#
#   Feedback_Score Sales_Agent Loyalty_Level Coupon_Code  Remarks
# 0              3         NaN           VIP      SAVE10     Late
# ...

# %%
len(closed_orders)
# Out:
# 3

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'], errors='coerce')
df['Delivery_Date'] = pd.to_datetime(df['Delivery_Date'], errors='coerce')

# %%
late_orders = df[(df['Delivery_Date'] - df['Order_Date']).dt.days > 7]
late_orders
# Out:
# Empty DataFrame
# Columns: [Order_ID, Customer_ID, Product_ID, Order_Date, Delivery_Date, Region, Country, Store_Name, Customer_Name, Email, Phone, Gender, Age, City, State, Account_Status, Product_Name, Category, Sub_Category, Brand, Supplier_Name, Discount, Price, Quantity, Payment_Mode, Payment_Status, Shipping_Cost, Total_Amount, Return_Status, Profit, Feedback_Score, Sales_Agent, Loyalty_Level, Coupon_Code, Remarks]
# Index: []
#
# [0 rows x 35 columns]

# %%
late_orders[['Order_ID', 'Order_Date', 'Delivery_Date']]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Delivery_Date]
# Index: []

# %%
len(late_orders)
# Out:
# 0

# %%
electronics_products = df[df['Category'] == 'Electronics']
electronics_products
# Out:
#   Order_ID Customer_ID Product_ID Order_Date Delivery_Date Region Country  \
# 0  ORD1000    CUST8471   PROD7862        NaT           NaT   West     USA
#
#   Store_Name Customer_Name                Email  ... Payment_Status  \
# 0   Flipkart          Amit  noemail@example.com  ...            NaN
#
#   Shipping_Cost  Total_Amount Return_Status   Profit Feedback_Score  \
# 0         755.0      199323.0       Pending  22394.0              3
#
#   Sales_Agent Loyalty_Level Coupon_Code Remarks
# 0         NaN           VIP      SAVE10    Late
#
# [1 rows x 35 columns]

# %%
electronics_products[['Product_ID', 'Product_Name', 'Category']]
# Out:
#   Product_ID Product_Name     Category
# 0   PROD7862           TV  Electronics

# %%
len(electronics_products)
# Out:
# 1

# %%
india_customers = df[df['Country'] == 'India']
india_customers
# Out:
# Empty DataFrame
# Columns: [Order_ID, Customer_ID, Product_ID, Order_Date, Delivery_Date, Region, Country, Store_Name, Customer_Name, Email, Phone, Gender, Age, City, State, Account_Status, Product_Name, Category, Sub_Category, Brand, Supplier_Name, Discount, Price, Quantity, Payment_Mode, Payment_Status, Shipping_Cost, Total_Amount, Return_Status, Profit, Feedback_Score, Sales_Agent, Loyalty_Level, Coupon_Code, Remarks]
# Index: []
#
# [0 rows x 35 columns]

# %%
len(india_customers)
# Out:
# 0

# %%
high_quantity_orders = df[df['Quantity'] > 10]
high_quantity_orders
# Out:
#    Order_ID Customer_ID Product_ID Order_Date Delivery_Date   Region  \
# 0   ORD1000    CUST8471   PROD7862        NaT           NaT     West
# 1   ORD1001    CUST5056   PROD7934        NaT           NaT  Unknown
# 9   ORD1009    CUST9968    PROD538        NaT           NaT  Unknown
# 12  ORD1012    CUST2051   PROD2742        NaT           NaT  Unknown
#
#       Country Store_Name Customer_Name                Email  ...  \
# 0         USA   Flipkart          Amit  noemail@example.com  ...
# 1   Australia     Amazon       Unknown       amit@yahoo.com  ...
# 9     Unknown    Walmart          Amit       mary@gmail.com  ...
# 12        USA     Target          Ravi                 ravi  ...
#
#    Payment_Status Shipping_Cost  Total_Amount Return_Status   Profit  \
# 0             NaN         755.0      199323.0       Pending  22394.0
# 1             NaN         389.0      137570.0  Not Returned  49832.0
# 9            Paid         443.0      169930.0      Returned  35381.0
# ...

# %%
high_quantity_orders[['Order_ID', 'Product_Name', 'Quantity']]
# Out:
#    Order_ID  Product_Name  Quantity
# 0   ORD1000            TV      14.0
# 1   ORD1001        Laptop      25.0
# 9   ORD1009  Misc Product      14.0
# 12  ORD1012        Laptop      49.0

# %%
len(high_quantity_orders)
# Out:
# 4

# %%
high_discount_orders = df[df['Discount'] > 50]
high_discount_orders
# Out:
#    Order_ID Customer_ID Product_ID Order_Date Delivery_Date   Region  \
# 1   ORD1001    CUST5056   PROD7934        NaT           NaT  Unknown
# 12  ORD1012    CUST2051   PROD2742        NaT           NaT  Unknown
#
#       Country Store_Name Customer_Name           Email  ... Payment_Status  \
# 1   Australia     Amazon       Unknown  amit@yahoo.com  ...            NaN
# 12        USA     Target          Ravi            ravi  ...         Failed
#
#    Shipping_Cost  Total_Amount Return_Status   Profit Feedback_Score  \
# 1          389.0      137570.0  Not Returned  49832.0              0
# 12         471.0      171053.0           NaN      NaN              2
#
#    Sales_Agent Loyalty_Level Coupon_Code    Remarks
# 1        Rahul          Gold         NaN        NaN
# 12        Sita           VIP         NaN  Delivered
#
# [2 rows x 35 columns]

# %%
high_discount_orders[['Order_ID', 'Product_Name', 'Discount']]
# Out:
#    Order_ID Product_Name  Discount
# 1   ORD1001       Laptop      68.0
# 12  ORD1012       Laptop      68.0

# %%
len(high_discount_orders)
# Out:
# 2

# %%
high_value_orders = df[(df['Price'] * df['Quantity']) > 100000]
high_value_orders
# Out:
#    Order_ID Customer_ID Product_ID Order_Date Delivery_Date   Region  \
# 0   ORD1000    CUST8471   PROD7862        NaT           NaT     West
# 1   ORD1001    CUST5056   PROD7934        NaT           NaT  Unknown
# 9   ORD1009    CUST9968    PROD538        NaT           NaT  Unknown
# 12  ORD1012    CUST2051   PROD2742        NaT           NaT  Unknown
#
#       Country Store_Name Customer_Name                Email  ...  \
# 0         USA   Flipkart          Amit  noemail@example.com  ...
# 1   Australia     Amazon       Unknown       amit@yahoo.com  ...
# 9     Unknown    Walmart          Amit       mary@gmail.com  ...
# 12        USA     Target          Ravi                 ravi  ...
#
#    Payment_Status Shipping_Cost  Total_Amount Return_Status   Profit  \
# 0             NaN         755.0      199323.0       Pending  22394.0
# 1             NaN         389.0      137570.0  Not Returned  49832.0
# 9            Paid         443.0      169930.0      Returned  35381.0
# ...

# %%
high_value_orders[['Order_ID', 'Product_Name', 'Price', 'Quantity']]
# Out:
#    Order_ID  Product_Name    Price  Quantity
# 0   ORD1000            TV  52766.0      14.0
# 1   ORD1001        Laptop  82505.0      25.0
# 9   ORD1009  Misc Product  62535.0      14.0
# 12  ORD1012        Laptop  78978.0      49.0

# %%
len(high_value_orders)
# Out:
# 4

# %%
customers = df[['Customer_ID', 'Customer_Name', 'Email']].drop_duplicates()

# %%
orders_with_customers = pd.merge(df, customers, on='Customer_ID', how='left')
orders_with_customers
# Out:
#   Order_ID Customer_ID Product_ID Order_Date Delivery_Date   Region  \
# 0  ORD1000    CUST8471   PROD7862        NaT           NaT     West
# 1  ORD1001    CUST5056   PROD7934        NaT           NaT  Unknown
# 2  ORD1009    CUST9968    PROD538        NaT           NaT  Unknown
# 3  ORD1012    CUST2051   PROD2742        NaT           NaT  Unknown
#
#      Country Store_Name Customer_Name_x              Email_x  ...  \
# 0        USA   Flipkart            Amit  noemail@example.com  ...
# 1  Australia     Amazon         Unknown       amit@yahoo.com  ...
# 2    Unknown    Walmart            Amit       mary@gmail.com  ...
# 3        USA     Target            Ravi                 ravi  ...
#
#   Total_Amount Return_Status   Profit Feedback_Score Sales_Agent  \
# 0     199323.0       Pending  22394.0              3         NaN
# 1     137570.0  Not Returned  49832.0              0       Rahul
# 2     169930.0      Returned  35381.0              2         NaN
# ...

# %%
orders_with_customers[['Order_ID', 'Customer_ID', 'Customer_Name_x', 'Email_x']]
# Out:
#   Order_ID Customer_ID Customer_Name_x              Email_x
# 0  ORD1000    CUST8471            Amit  noemail@example.com
# 1  ORD1001    CUST5056         Unknown       amit@yahoo.com
# 2  ORD1009    CUST9968            Amit       mary@gmail.com
# 3  ORD1012    CUST2051            Ravi                 ravi

# %%
len(orders_with_customers)
# Out:
# 4

# %%
products = df[['Product_ID', 'Product_Name', 'Category']].drop_duplicates()

# %%
orders_with_products = pd.merge(df, products, on='Product_ID', how='left')
orders_with_products
# Out:
#   Order_ID Customer_ID Product_ID Order_Date Delivery_Date   Region  \
# 0  ORD1000    CUST8471   PROD7862        NaT           NaT     West
# 1  ORD1001    CUST5056   PROD7934        NaT           NaT  Unknown
# 2  ORD1009    CUST9968    PROD538        NaT           NaT  Unknown
# 3  ORD1012    CUST2051   PROD2742        NaT           NaT  Unknown
#
#      Country Store_Name Customer_Name                Email  ... Total_Amount  \
# 0        USA   Flipkart          Amit  noemail@example.com  ...     199323.0
# 1  Australia     Amazon       Unknown       amit@yahoo.com  ...     137570.0
# 2    Unknown    Walmart          Amit       mary@gmail.com  ...     169930.0
# 3        USA     Target          Ravi                 ravi  ...     171053.0
#
#   Return_Status   Profit Feedback_Score Sales_Agent Loyalty_Level Coupon_Code  \
# 0       Pending  22394.0              3         NaN           VIP      SAVE10
# 1  Not Returned  49832.0              0       Rahul          Gold         NaN
# ...

# %%
orders_with_products[['Order_ID', 'Product_ID', 'Product_Name_y', 'Category_y']]
# Out:
#   Order_ID Product_ID Product_Name_y   Category_y
# 0  ORD1000   PROD7862             TV  Electronics
# 1  ORD1001   PROD7934         Laptop      Fashion
# 2  ORD1009    PROD538   Misc Product      Grocery
# 3  ORD1012   PROD2742         Laptop       Others

# %%
len(orders_with_products)
# Out:
# 4

# %%
customer_total = df.groupby('Customer_ID').apply(
    lambda x: (x['Price'] * x['Quantity']).sum()
)

customer_total
# Out:
# /tmp/ipython-input-2730851623.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   customer_total = df.groupby('Customer_ID').apply(
# Customer_ID
# CUST2051    3869922.0
# CUST5056    2062625.0
# CUST8471     738724.0
# CUST9968     875490.0
# dtype: float64

# %%
customer_total = (df['Price'] * df['Quantity']).groupby(df['Customer_ID']).sum()
customer_total
# Out:
# Customer_ID
# CUST2051    3869922.0
# CUST5056    2062625.0
# CUST8471     738724.0
# CUST9968     875490.0
# dtype: float64

# %%
customer_total.head()
# Out:
# Customer_ID
# CUST2051    3869922.0
# CUST5056    2062625.0
# CUST8471     738724.0
# CUST9968     875490.0
# dtype: float64

# %%
customer_total = customer_total.reset_index(name='Total_Purchase_Amount')
customer_total
# Out:
#   Customer_ID  Total_Purchase_Amount
# 0    CUST2051              3869922.0
# 1    CUST5056              2062625.0
# 2    CUST8471               738724.0
# 3    CUST9968               875490.0

# %%
avg_profit = df.groupby('Category')['Profit'].mean()
avg_profit
# Out:
# Category
# Electronics    22394.0
# Fashion        49832.0
# Grocery        35381.0
# Others             NaN
# Name: Profit, dtype: float64

# %%
avg_profit = avg_profit.reset_index(name='Average_Profit')
avg_profit
# Out:
#       Category  Average_Profit
# 0  Electronics         22394.0
# 1      Fashion         49832.0
# 2      Grocery         35381.0
# 3       Others             NaN

# %%
avg_profit.head()
# Out:
#       Category  Average_Profit
# 0  Electronics         22394.0
# 1      Fashion         49832.0
# 2      Grocery         35381.0
# 3       Others             NaN

# %%
electronics_customers = df[df['Category'] == 'Electronics']
electronics_customers[['Customer_ID', 'Category']]
# Out:
#   Customer_ID     Category
# 0    CUST8471  Electronics

# %%
electronics_customers['Customer_ID'].unique()
# Out:
# array(['CUST8471'], dtype=object)

# %%
df[df['Loyalty_Level'] == 'VIP'].assign(Total=df['Price']*df['Quantity'])\
.groupby('Customer_ID')['Total'].sum().sort_values(ascending=False).head(10)
# Out:
# Customer_ID
# CUST2051    3869922.0
# CUST8471     738724.0
# Name: Total, dtype: float64

# %%
all_products = df[['Product_ID', 'Product_Name']].drop_duplicates()

# %%
ordered_products = df['Product_ID'].drop_duplicates()

# %%
never_ordered = pd.DataFrame(columns=['Product_ID', 'Product_Name'])
never_ordered
# Out:
# Empty DataFrame
# Columns: [Product_ID, Product_Name]
# Index: []

# %%
missing_customer_info = df[
    df['Customer_Name'].isna() |
    df['Email'].isna() |
    df['Phone'].isna()
]

missing_customer_info
# Out:
# Empty DataFrame
# Columns: [Order_ID, Customer_ID, Product_ID, Order_Date, Delivery_Date, Region, Country, Store_Name, Customer_Name, Email, Phone, Gender, Age, City, State, Account_Status, Product_Name, Category, Sub_Category, Brand, Supplier_Name, Discount, Price, Quantity, Payment_Mode, Payment_Status, Shipping_Cost, Total_Amount, Return_Status, Profit, Feedback_Score, Sales_Agent, Loyalty_Level, Coupon_Code, Remarks]
# Index: []
#
# [0 rows x 35 columns]

# %%
missing_customer_info[['Order_ID', 'Customer_ID', 'Customer_Name', 'Email', 'Phone']]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Customer_ID, Customer_Name, Email, Phone]
# Index: []

# %%
len(missing_customer_info)
# Out:
# 0

# %%
missing_product_info = df[
    df['Product_Name'].isna() |
    df['Category'].isna() |
    df['Price'].isna()
]

missing_product_info
# Out:
# Empty DataFrame
# Columns: [Order_ID, Customer_ID, Product_ID, Order_Date, Delivery_Date, Region, Country, Store_Name, Customer_Name, Email, Phone, Gender, Age, City, State, Account_Status, Product_Name, Category, Sub_Category, Brand, Supplier_Name, Discount, Price, Quantity, Payment_Mode, Payment_Status, Shipping_Cost, Total_Amount, Return_Status, Profit, Feedback_Score, Sales_Agent, Loyalty_Level, Coupon_Code, Remarks]
# Index: []
#
# [0 rows x 35 columns]

# %%
missing_product_info[['Order_ID', 'Product_ID', 'Product_Name', 'Category', 'Price']]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Product_ID, Product_Name, Category, Price]
# Index: []

# %%
len(missing_product_info)
# Out:
# 0

# %%
df['Total_Purchase'] = df['Price'] * df['Quantity']

# %%
df[['Order_ID', 'Price', 'Quantity', 'Total_Purchase']].head(10)
# Out:
#    Order_ID    Price  Quantity  Total_Purchase
# 0   ORD1000  52766.0      14.0        738724.0
# 1   ORD1001  82505.0      25.0       2062625.0
# 9   ORD1009  62535.0      14.0        875490.0
# 12  ORD1012  78978.0      49.0       3869922.0

# %%
df['Discounted_Price'] = df['Price'] - (df['Price'] * df['Discount'] / 100)

# %%
df[['Order_ID', 'Price', 'Discount', 'Discounted_Price']].head(10)
# Out:
#    Order_ID    Price  Discount  Discounted_Price
# 0   ORD1000  52766.0      40.0          31659.60
# 1   ORD1001  82505.0      68.0          26401.60
# 9   ORD1009  62535.0       0.0          62535.00
# 12  ORD1012  78978.0      68.0          25272.96

# %%
df['Order_Date'] = pd.to_datetime(df['Order_Date'], errors='coerce')
df['Delivery_Date'] = pd.to_datetime(df['Delivery_Date'], errors='coerce')

# %%
df.loc[:, 'Order_Date'] = pd.to_datetime(df['Order_Date'], errors='coerce')
df.loc[:, 'Delivery_Date'] = pd.to_datetime(df['Delivery_Date'], errors='coerce')

# %%
print(df)
# Out:
#    Order_ID Customer_ID Product_ID Order_Date Delivery_Date   Region  \
# 0   ORD1000    CUST8471   PROD7862        NaT           NaT     West
# 1   ORD1001    CUST5056   PROD7934        NaT           NaT  Unknown
# 9   ORD1009    CUST9968    PROD538        NaT           NaT  Unknown
# 12  ORD1012    CUST2051   PROD2742        NaT           NaT  Unknown
#
#       Country Store_Name Customer_Name                Email  ... Total_Amount  \
# 0         USA   Flipkart          Amit  noemail@example.com  ...     199323.0
# 1   Australia     Amazon       Unknown       amit@yahoo.com  ...     137570.0
# 9     Unknown    Walmart          Amit       mary@gmail.com  ...     169930.0
# 12        USA     Target          Ravi                 ravi  ...     171053.0
#
#    Return_Status   Profit Feedback_Score Sales_Agent Loyalty_Level  \
# 0        Pending  22394.0              3         NaN           VIP
# 1   Not Returned  49832.0              0       Rahul          Gold
# ...

# %%
df['Age_Group'] = df['Age'].apply(
    lambda x: 'Child' if x <= 12
    else 'Teen' if x <= 19
    else 'Adult' if x <= 59
    else 'Senior'
)
df[['Age', 'Age_Group']].head(10)
# Out:
#       Age Age_Group
# 0    61.0    Senior
# 1   116.0    Senior
# 9    69.0    Senior
# 12   40.0     Adult

# %%
df['Profit_Margin'] = (df['Profit'] / df['Total_Amount']) * 100

# %%
df = df.copy()

# %%
df.loc[:, 'Gender_Code'] = df['Gender'].map({
    'Male': 1,
    'Female': 2,
    'Other': 3
})

# %%
df[['Gender', 'Gender_Code']].head(10)
# Out:
#     Gender  Gender_Code
# 0   Female            2
# 1    Other            3
# 9   Female            2
# 12  Female            2

# %%
df.loc[:, 'Payment_Code'] = df['Payment_Mode'].map({
    'Cash': 1,
    'Card': 2,
    'UPI': 3,
    'Net Banking': 4,
    'Other': 5
})

# %%
df[['Gender', 'Gender_Code']].head(10)
# Out:
#     Gender  Gender_Code
# 0   Female            2
# 1    Other            3
# 9   Female            2
# 12  Female            2

# %%
df.loc[:, 'Country'] = df['Country'].str.capitalize()

# %%
df[['Country']].head(20)
# Out:
#       Country
# 0         Usa
# 1   Australia
# 9     Unknown
# 12        Usa

# %%
df = df.copy()

text_cols = df.select_dtypes(include=['object']).columns
df[text_cols] = df[text_cols].apply(lambda col: col.str.strip())

# %%
df.head()
# Out:
#    Order_ID Customer_ID Product_ID Order_Date Delivery_Date   Region  \
# 0   ORD1000    CUST8471   PROD7862        NaT           NaT     West
# 1   ORD1001    CUST5056   PROD7934        NaT           NaT  Unknown
# 9   ORD1009    CUST9968    PROD538        NaT           NaT  Unknown
# 12  ORD1012    CUST2051   PROD2742        NaT           NaT  Unknown
#
#       Country Store_Name Customer_Name                Email  ... Sales_Agent  \
# 0         Usa   Flipkart          Amit  noemail@example.com  ...         NaN
# 1   Australia     Amazon       Unknown       amit@yahoo.com  ...       Rahul
# 9     Unknown    Walmart          Amit       mary@gmail.com  ...         NaN
# 12        Usa     Target          Ravi                 ravi  ...        Sita
#
#    Loyalty_Level  Coupon_Code    Remarks Total_Purchase Discounted_Price  \
# 0            VIP       SAVE10       Late       738724.0         31659.60
# 1           Gold          NaN        NaN      2062625.0         26401.60
# ...

# %%
df.loc[:, 'Order_Date'] = pd.to_datetime(df['Order_Date'], errors='coerce')
df.loc[:, 'Delivery_Date'] = pd.to_datetime(df['Delivery_Date'], errors='coerce')

# %%
df[['Order_Date', 'Delivery_Date']].head(10)
# Out:
#    Order_Date Delivery_Date
# 0         NaT           NaT
# 1         NaT           NaT
# 9         NaT           NaT
# 12        NaT           NaT

# %%
(df['Price'] * df['Quantity']).groupby(df['Product_Name']).sum().sort_values(ascending=False).head(5)
# Out:
# Product_Name
# Laptop          5932547.0
# Misc Product     875490.0
# TV               738724.0
# dtype: float64

# %%
(df['Price'] * df['Quantity']).groupby(df['Product_Name']).sum().sort_values(ascending=False).head(5).reset_index()
# Out:
#    Product_Name          0
# 0        Laptop  5932547.0
# 1  Misc Product   875490.0
# 2            TV   738724.0

# %%
df['Total_Purchase'] = df['Price'] * df['Quantity']
customer_group = df.groupby('Customer_ID')['Total_Purchase'].sum()
sorted_customers = customer_group.sort_values(ascending=False)

# %%
top_5_customers = sorted_customers.head(5)
top_5_customers
# Out:
# Customer_ID
# CUST2051    3869922.0
# CUST5056    2062625.0
# CUST9968     875490.0
# CUST8471     738724.0
# Name: Total_Purchase, dtype: float64

# %%
avg_discount = df.groupby('Category')['Discount'].mean()
avg_discount
# Out:
# Category
# Electronics    40.0
# Fashion        68.0
# Grocery         0.0
# Others         68.0
# Name: Discount, dtype: float64

# %%
avg_discount = avg_discount.reset_index(name='Average_Discount')
avg_discount
# Out:
#       Category  Average_Discount
# 0  Electronics              40.0
# 1      Fashion              68.0
# 2      Grocery               0.0
# 3       Others              68.0

# %%
avg_feedback = df.groupby('Product_Name')['Feedback_Score'].mean()
avg_feedback
# Out:
# Product_Name
# Laptop          1.0
# Misc Product    2.0
# TV              3.0
# Name: Feedback_Score, dtype: float64

# %%
avg_feedback = avg_feedback.reset_index(name='Average_Feedback_Score')
avg_feedback
# Out:
#    Product_Name  Average_Feedback_Score
# 0        Laptop                     1.0
# 1  Misc Product                     2.0
# 2            TV                     3.0

# %%
df['Payment_Mode'].value_counts().head(1)
df
# Out:
#    Order_ID Customer_ID Product_ID Order_Date Delivery_Date   Region  \
# 0   ORD1000    CUST8471   PROD7862        NaT           NaT     West
# 1   ORD1001    CUST5056   PROD7934        NaT           NaT  Unknown
# 9   ORD1009    CUST9968    PROD538        NaT           NaT  Unknown
# 12  ORD1012    CUST2051   PROD2742        NaT           NaT  Unknown
#
#       Country Store_Name Customer_Name                Email  ... Sales_Agent  \
# 0         Usa   Flipkart          Amit  noemail@example.com  ...         NaN
# 1   Australia     Amazon       Unknown       amit@yahoo.com  ...       Rahul
# 9     Unknown    Walmart          Amit       mary@gmail.com  ...         NaN
# 12        Usa     Target          Ravi                 ravi  ...        Sita
#
#    Loyalty_Level  Coupon_Code    Remarks Total_Purchase Discounted_Price  \
# 0            VIP       SAVE10       Late       738724.0         31659.60
# 1           Gold          NaN        NaN      2062625.0         26401.60
# ...

# %%
df.groupby('Customer_ID')['Order_ID'].count()[lambda x: x > 5]
# Out:
# Series([], Name: Order_ID, dtype: int64)

# %%
sorted_orders = df.sort_values(by='Profit', ascending=False)
sorted_orders
# Out:
#    Order_ID Customer_ID Product_ID Order_Date Delivery_Date   Region  \
# 1   ORD1001    CUST5056   PROD7934        NaT           NaT  Unknown
# 9   ORD1009    CUST9968    PROD538        NaT           NaT  Unknown
# 0   ORD1000    CUST8471   PROD7862        NaT           NaT     West
# 12  ORD1012    CUST2051   PROD2742        NaT           NaT  Unknown
#
#       Country Store_Name Customer_Name                Email  ... Sales_Agent  \
# 1   Australia     Amazon       Unknown       amit@yahoo.com  ...       Rahul
# 9     Unknown    Walmart          Amit       mary@gmail.com  ...         NaN
# 0         Usa   Flipkart          Amit  noemail@example.com  ...         NaN
# 12        Usa     Target          Ravi                 ravi  ...        Sita
#
#    Loyalty_Level  Coupon_Code    Remarks Total_Purchase Discounted_Price  \
# 1           Gold          NaN        NaN      2062625.0         26401.60
# 9            NaN       SAVE10    Damaged       875490.0         62535.00
# ...

# %%
sorted_orders[['Order_ID', 'Customer_Name', 'Profit']]
# Out:
#    Order_ID Customer_Name   Profit
# 1   ORD1001       Unknown  49832.0
# 9   ORD1009          Amit  35381.0
# 0   ORD1000          Amit  22394.0
# 12  ORD1012          Ravi      NaN

# %%
avg_feedback = df.groupby('Product_Name')['Feedback_Score'].mean()

# %%
max_feedback_product = avg_feedback.idxmax()
max_feedback_value = avg_feedback.max()

max_feedback_product, max_feedback_value
# Out:
# ('TV', 3.0)

# %%
min_feedback_product = avg_feedback.idxmin()
min_feedback_value = avg_feedback.min()

min_feedback_product, min_feedback_value
# Out:
# ('Laptop', 1.0)

# %%
avg_feedback.reset_index()
# Out:
#    Product_Name  Feedback_Score
# 0        Laptop             1.0
# 1  Misc Product             2.0
# 2            TV             3.0

# %%
df.groupby(['Country', 'Category'])['Total_Amount'].sum()
# Out:
# Country    Category
# Australia  Fashion        137570.0
# Unknown    Grocery        169930.0
# Usa        Electronics    199323.0
#            Others         171053.0
# Name: Total_Amount, dtype: float64

# %%
df.groupby(['Country', 'Category'])['Total_Amount'].sum().reset_index()
# Out:
#      Country     Category  Total_Amount
# 0  Australia      Fashion      137570.0
# 1    Unknown      Grocery      169930.0
# 2        Usa  Electronics      199323.0
# 3        Usa       Others      171053.0

# %%
expected_amount = df['Price'] * df['Quantity']

# %%
invalid_rows = df[df['Total_Amount'] < expected_amount]
invalid_rows
# Out:
#    Order_ID Customer_ID Product_ID Order_Date Delivery_Date   Region  \
# 0   ORD1000    CUST8471   PROD7862        NaT           NaT     West
# 1   ORD1001    CUST5056   PROD7934        NaT           NaT  Unknown
# 9   ORD1009    CUST9968    PROD538        NaT           NaT  Unknown
# 12  ORD1012    CUST2051   PROD2742        NaT           NaT  Unknown
#
#       Country Store_Name Customer_Name                Email  ... Sales_Agent  \
# 0         Usa   Flipkart          Amit  noemail@example.com  ...         NaN
# 1   Australia     Amazon       Unknown       amit@yahoo.com  ...       Rahul
# 9     Unknown    Walmart          Amit       mary@gmail.com  ...         NaN
# 12        Usa     Target          Ravi                 ravi  ...        Sita
#
#    Loyalty_Level  Coupon_Code    Remarks Total_Purchase Discounted_Price  \
# 0            VIP       SAVE10       Late       738724.0         31659.60
# 1           Gold          NaN        NaN      2062625.0         26401.60
# ...

# %%
len(invalid_rows)
# Out:
# 4

# %%
df['Delivery_Duration'] = (df['Delivery_Date'] - df['Order_Date']).dt.days

# %%
invalid_delivery = df[df['Delivery_Duration'] < 0]
invalid_delivery
# Out:
# Empty DataFrame
# Columns: [Order_ID, Customer_ID, Product_ID, Order_Date, Delivery_Date, Region, Country, Store_Name, Customer_Name, Email, Phone, Gender, Age, City, State, Account_Status, Product_Name, Category, Sub_Category, Brand, Supplier_Name, Discount, Price, Quantity, Payment_Mode, Payment_Status, Shipping_Cost, Total_Amount, Return_Status, Profit, Feedback_Score, Sales_Agent, Loyalty_Level, Coupon_Code, Remarks, Total_Purchase, Discounted_Price, Age_Group, Profit_Margin, Gender_Code, Payment_Code, Delivery_Duration]
# Index: []
#
# [0 rows x 42 columns]

# %%
len(invalid_delivery)
# Out:
# 0

# %%
df.drop(df[df['Delivery_Duration'] < 0].index, inplace=True)

# %%
len(df[df['Delivery_Duration'] < 0])
# Out:
# 0

# %%
df['Delivery_Duration'] = (df['Delivery_Date'] - df['Order_Date']).dt.days

# %%
long_delivery_orders = df[df['Delivery_Duration'] > 30]
long_delivery_orders
# Out:
# Empty DataFrame
# Columns: [Order_ID, Customer_ID, Product_ID, Order_Date, Delivery_Date, Region, Country, Store_Name, Customer_Name, Email, Phone, Gender, Age, City, State, Account_Status, Product_Name, Category, Sub_Category, Brand, Supplier_Name, Discount, Price, Quantity, Payment_Mode, Payment_Status, Shipping_Cost, Total_Amount, Return_Status, Profit, Feedback_Score, Sales_Agent, Loyalty_Level, Coupon_Code, Remarks, Total_Purchase, Discounted_Price, Age_Group, Profit_Margin, Gender_Code, Payment_Code, Delivery_Duration]
# Index: []
#
# [0 rows x 42 columns]

# %%
len(long_delivery_orders)
# Out:
# 0

# %%
long_delivery_orders[['Order_ID', 'Order_Date', 'Delivery_Date', 'Delivery_Duration']]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Delivery_Date, Delivery_Duration]
# Index: []

# %%
invalid_phone_numbers = df[df['Phone'].astype(str).str.len() < 10]
invalid_phone_numbers[['Order_ID', 'Customer_ID', 'Phone']]
# Out:
#    Order_ID Customer_ID  Phone
# 0   ORD1000    CUST8471  12345
# 1   ORD1001    CUST5056  12345
# 9   ORD1009    CUST9968  12345
# 12  ORD1012    CUST2051  12345

# %%
df['Invalid_Total_Amount'] = df['Total_Amount'] < 0

# %%
df[['Order_ID', 'Total_Amount', 'Invalid_Total_Amount']].head(10)
# Out:
#    Order_ID  Total_Amount  Invalid_Total_Amount
# 0   ORD1000      199323.0                 False
# 1   ORD1001      137570.0                 False
# 9   ORD1009      169930.0                 False
# 12  ORD1012      171053.0                 False

# %%
df['Invalid_Total_Amount'].sum()
# Out:
# np.int64(0)

# %%
# Convert date columns to the same format
for col in ['Order_Date', 'Delivery_Date']:
    df[col] = pd.to_datetime(df[col], errors='coerce').dt.strftime('%Y-%m-%d')

# %%
df[['Order_Date', 'Delivery_Date']].head()
# Out:
#    Order_Date Delivery_Date
# 0         NaN           NaN
# 1         NaN           NaN
# 9         NaN           NaN
# 12        NaN           NaN

# %%
df.dtypes
df.head()
# Out:
#    Order_ID Customer_ID Product_ID Order_Date Delivery_Date   Region  \
# 0   ORD1000    CUST8471   PROD7862        NaN           NaN     West
# 1   ORD1001    CUST5056   PROD7934        NaN           NaN  Unknown
# 9   ORD1009    CUST9968    PROD538        NaN           NaN  Unknown
# 12  ORD1012    CUST2051   PROD2742        NaN           NaN  Unknown
#
#       Country Store_Name Customer_Name                Email  ... Coupon_Code  \
# 0         Usa   Flipkart          Amit  noemail@example.com  ...      SAVE10
# 1   Australia     Amazon       Unknown       amit@yahoo.com  ...         NaN
# 9     Unknown    Walmart          Amit       mary@gmail.com  ...      SAVE10
# 12        Usa     Target          Ravi                 ravi  ...         NaN
#
#       Remarks  Total_Purchase Discounted_Price Age_Group Profit_Margin  \
# 0        Late        738724.0         31659.60    Senior     11.235031
# 1         NaN       2062625.0         26401.60    Senior     36.223014
# ...

# %%
#Standardize Brand and Supplier_Name Capitalization
df[['Brand', 'Supplier_Name']].head()
# Out:
#     Brand     Supplier_Name
# 0   Apple          XYZ Corp
# 1      LG  Global Suppliers
# 9    Sony               NaN
# 12  Apple       ABC Traders

# %%
df['Brand'] = df['Brand'].str.title()
df['Supplier_Name'] = df['Supplier_Name'].str.title()

# %%
df[['Brand', 'Supplier_Name']].drop_duplicates().head(10)
# Out:
#     Brand     Supplier_Name
# 0   Apple          Xyz Corp
# 1      Lg  Global Suppliers
# 9    Sony               NaN
# 12  Apple       Abc Traders

# %%
df['Profit'].isnull().sum()
# Out:
# np.int64(1)

# %%
Q1 = df['Profit'].quantile(0.25)
Q3 = df['Profit'].quantile(0.75)

# %%
IQR = Q3 - Q1

# %%
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# %%
profit_outliers = df[
    (df['Profit'] < lower_bound) |
    (df['Profit'] > upper_bound)
]

# %%
profit_outliers[['Profit']]
# Out:
# Empty DataFrame
# Columns: [Profit]
# Index: []

# %%
df['Profit'].describe()
# Out:
# count        3.000000
# mean     35869.000000
# std      13725.507969
# min      22394.000000
# 25%      28887.500000
# 50%      35381.000000
# 75%      42606.500000
# max      49832.000000
# Name: Profit, dtype: float64

# %%
profit_outliers.shape
# Out:
# (0, 43)

# %%
df.columns
# Out:
# Index(['Order_ID', 'Customer_ID', 'Product_ID', 'Order_Date', 'Delivery_Date',
#        'Region', 'Country', 'Store_Name', 'Customer_Name', 'Email', 'Phone',
#        'Gender', 'Age', 'City', 'State', 'Account_Status', 'Product_Name',
#        'Category', 'Sub_Category', 'Brand', 'Supplier_Name', 'Discount',
#        'Price', 'Quantity', 'Payment_Mode', 'Payment_Status', 'Shipping_Cost',
#        'Total_Amount', 'Return_Status', 'Profit', 'Feedback_Score',
#        'Sales_Agent', 'Loyalty_Level', 'Coupon_Code', 'Remarks',
#        'Total_Purchase', 'Discounted_Price', 'Age_Group', 'Profit_Margin',
#        'Gender_Code', 'Payment_Code', 'Delivery_Duration',
#        'Invalid_Total_Amount'],
#       dtype='object')

# %%
df['Feedback_Score'].describe()
# Out:
# count    4.000000
# mean     1.750000
# std      1.258306
# min      0.000000
# 25%      1.500000
# 50%      2.000000
# 75%      2.250000
# max      3.000000
# Name: Feedback_Score, dtype: float64

# %%
import numpy as np

df.loc[
    (df['Feedback_Score'] > 5) | (df['Feedback_Score'] < 0),
    'Feedback_Score'
] = np.nan

# %%
df['Feedback_Score'].isnull().sum()
# Out:
# np.int64(0)

# %%
df[['Feedback_Score']].head()
# Out:
#     Feedback_Score
# 0              3.0
# 1              0.0
# 9              2.0
# 12             2.0

# %%
#Validate Missing Payment_Status for “Paid” Orders
df['Payment_Status'].isnull().sum()
# Out:
# np.int64(2)

# %%
invalid_payment_status = df[
    (df['Payment_Status'].isna()) &
    (df['Payment_Mode'] == 'Paid')
]

# %%
invalid_payment_status[['Order_ID', 'Payment_Status', 'Payment_Mode']]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Payment_Status, Payment_Mode]
# Index: []

# %%
invalid_payment_status.shape[0]
# Out:
# 0
